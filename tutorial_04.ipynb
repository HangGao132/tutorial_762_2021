# %% [markdown]
# # Creating a CNN for MNIST dataset

# %%
import time
import os
import random

import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision as tv

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

num_workers = os.cpu_count()
print(num_workers)
# Out:
# cuda:0
# 24

# %%
# Reset RNG seed
random_state = 12345

random_state = int(random_state)
random.seed(random_state)
np.random.seed(random_state)
torch.manual_seed(random_state)
torch.cuda.manual_seed_all(random_state)
torch.backends.cudnn.deterministic = True

# %%
batch_size = 256
lr = 0.001
epochs = 50

# %%
# Load data
root = 'data'

transform = tv.transforms.Compose([
        tv.transforms.ToTensor(),
])
train_dataset = tv.datasets.MNIST(
    root,
    train=True, 
    download=True,
    transform=transform)
test_dataset = tv.datasets.MNIST(
    root,
    train=False, 
    download=True,
    transform=transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
)
test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # We don't need to shuffle test set
)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, 3, 1)
        self.dropout1 = nn.Dropout2d(0.25)
        self.fc1 = nn.Linear(int(((28 - (3-1)) / 2)**2 * 8), 128)
        self.fc2 = nn.Linear(128, 10)
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)  # No need to call Softmax function
        return x
# CrossEntropyLoss combines LogSoftmax and NLLLoss

# %%
def train(model, loader, optimizer, loss):
    model.train()
    total_loss = 0.
    corrects = 0.
    
    for x, y in loader:
        x = x.to(device)
        y = y.to(device)
        batch_size = x.size(0)
        
        optimizer.zero_grad()
        output = model(x)
        los = loss(output, y)
        los.backward()
        optimizer.step()

        # for display
        total_loss += los.item() * batch_size
        preds = output.max(1, keepdim=True)[1]
        corrects += preds.eq(y.view_as(preds)).sum().item()
    
    n = len(loader.dataset)
    total_loss = total_loss / n
    accuracy = corrects / n
    return total_loss, accuracy

# %%
def validate(model, loader, loss):
    model.eval()
    total_loss = 0.
    corrects = 0.
    
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            y = y.to(device)
            batch_size = x.size(0)
            output = model(x)
            los = loss(output, y)
            total_loss += los.item() * batch_size
            preds = output.max(1, keepdim=True)[1]
            corrects += preds.eq(y.view_as(preds)).sum().item()
    
    n = len(loader.dataset)
    total_loss = total_loss / n
    accuracy = corrects / n
    return total_loss, accuracy

# %%
cnn = Net()

# %%
# Test model
x, _ = next(iter(test_loader))
print(x.size())

out = cnn(x)
print(out.size())
# Out:
# torch.Size([256, 1, 28, 28])
# torch.Size([256, 10])

# %%
# Move model to GPU
cnn.to(device)

# Define loss function and optimization method
optimizer = torch.optim.SGD(cnn.parameters(), lr=lr, momentum=0.9)
loss = nn.CrossEntropyLoss()

# %%
train_losses = np.zeros(epochs, dtype=np.float)
test_losses = np.zeros(epochs, dtype=np.float)
train_accs = np.zeros(epochs, dtype=np.float)
test_accs = np.zeros(epochs, dtype=np.float)

since = time.time()
for i, epoch in enumerate(range(epochs)):
    start = time.time()
    train_losses[i], train_accs[i] = train(cnn, train_loader, optimizer, loss)
    test_losses[i], test_accs[i] = validate(cnn, test_loader, loss)
    
    time_elapsed = time.time() - start
    print(('[{:2d}] {:.0f}m {:.1f}s Train Loss: {:.4f} Accuracy: {:.4f}%, ' +
        'Test Loss: {:.4f} Accuracy: {:.4f}%').format(
            epoch+1, time_elapsed // 60, time_elapsed % 60,
            train_losses[i], train_accs[i]*100.,
            test_losses[i], test_accs[i]*100.))
    
time_elapsed = time.time() - since
print('Total run time: {:.0f}m {:.1f}s'.format(
    time_elapsed // 60,
    time_elapsed % 60))
# Out:
# [ 1] 0m 4.9s Train Loss: 2.1851 Accuracy: 39.3683%, Test Loss: 1.8941 Accuracy: 69.3500%
# [ 2] 0m 3.3s Train Loss: 1.2397 Accuracy: 75.2050%, Test Loss: 0.6356 Accuracy: 85.5500%
# [28] 0m 3.4s Train Loss: 0.1763 Accuracy: 95.3000%, Test Loss: 0.1463 Accuracy: 95.7500%
# [29] 0m 3.4s Train Loss: 0.1720 Accuracy: 95.4150%, Test Loss: 0.1421 Accuracy: 95.8300%
# [30] 0m 3.3s Train Loss: 0.1685 Accuracy: 95.5000%, Test Loss: 0.1410 Accuracy: 95.7700%
# [31] 0m 3.3s Train Loss: 0.1645 Accuracy: 95.5800%, Test Loss: 0.1362 Accuracy: 96.0100%
# [32] 0m 3.3s Train Loss: 0.1617 Accuracy: 95.6650%, Test Loss: 0.1350 Accuracy: 96.0100%
# [33] 0m 3.3s Train Loss: 0.1576 Accuracy: 95.8333%, Test Loss: 0.1310 Accuracy: 96.1700%
# [34] 0m 3.4s Train Loss: 0.1538 Accuracy: 95.9433%, Test Loss: 0.1288 Accuracy: 96.1600%
# [35] 0m 3.3s Train Loss: 0.1509 Accuracy: 95.9367%, Test Loss: 0.1280 Accuracy: 96.2500%
# [36] 0m 3.3s Train Loss: 0.1484 Accuracy: 96.0167%, Test Loss: 0.1240 Accuracy: 96.3500%
# [37] 0m 3.3s Train Loss: 0.1441 Accuracy: 96.1500%, Test Loss: 0.1240 Accuracy: 96.3200%
# [38] 0m 3.3s Train Loss: 0.1420 Accuracy: 96.1733%, Test Loss: 0.1213 Accuracy: 96.3300%
# [39] 0m 3.3s Train Loss: 0.1381 Accuracy: 96.2583%, Test Loss: 0.1194 Accuracy: 96.4600%
# [40] 0m 3.3s Train Loss: 0.1359 Accuracy: 96.3083%, Test Loss: 0.1168 Accuracy: 96.5400%
# [41] 0m 3.3s Train Loss: 0.1338 Accuracy: 96.4233%, Test Loss: 0.1144 Accuracy: 96.5200%
# [42] 0m 3.3s Train Loss: 0.1305 Accuracy: 96.4767%, Test Loss: 0.1143 Accuracy: 96.6200%
# [43] 0m 3.3s Train Loss: 0.1288 Accuracy: 96.4800%, Test Loss: 0.1108 Accuracy: 96.6800%
# [44] 0m 3.3s Train Loss: 0.1263 Accuracy: 96.5333%, Test Loss: 0.1107 Accuracy: 96.8500%
# [45] 0m 3.3s Train Loss: 0.1252 Accuracy: 96.6317%, Test Loss: 0.1095 Accuracy: 96.7500%
# [46] 0m 3.4s Train Loss: 0.1222 Accuracy: 96.6600%, Test Loss: 0.1083 Accuracy: 96.7100%
# [47] 0m 3.3s Train Loss: 0.1207 Accuracy: 96.7717%, Test Loss: 0.1060 Accuracy: 96.8800%
# [48] 0m 3.3s Train Loss: 0.1177 Accuracy: 96.8233%, Test Loss: 0.1055 Accuracy: 96.8600%
# [49] 0m 3.3s Train Loss: 0.1168 Accuracy: 96.8733%, Test Loss: 0.1027 Accuracy: 96.9900%
# [50] 0m 3.3s Train Loss: 0.1154 Accuracy: 96.9567%, Test Loss: 0.1017 Accuracy: 97.0000%
# Total run time: 2m 48.3s

# %%
plt.figure()
plt.plot(range(epochs), train_losses, label='Train loss')
plt.plot(range(epochs), test_losses, label='Test loss')
plt.ylabel('Cross Entropy Loss')
plt.xlabel('Epochs')
plt.legend()
plt.title('Cross Entropy Losses of CNN on MNIST')
plt.show()

# %%
plt.figure()
plt.plot(range(epochs), train_accs*100.0, label='Train accuracy')
plt.plot(range(epochs), test_accs*100.0, label='Test accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.title('Accuracies of CNN on MNIST')
plt.show()
